# %% [markdown]
# Netflix Shows and Movies Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Import Data

# %%
First_netflix_data = pd.read_csv('./first_dataset.csv')

# %%
Second_netflix_data = pd.read_csv('./second_dataset.csv')

# %% [markdown]
# Summarize the data

# %%
First_netflix_data.describe()
# Out:
#                  id         year
# count  3.256000e+03  3256.000000
# mean   8.063665e+07  2019.364865
# std    1.936469e+06     2.704297
# min    7.004527e+07  2012.000000
# 25%    8.021615e+07  2018.000000
# 50%    8.112197e+07  2020.000000
# 75%    8.141198e+07  2022.000000
# max    8.171850e+07  2023.000000

# %% [markdown]
# View the column names

# %%
First_netflix_data.columns
# Out:
# Index(['title', 'type', 'genres', 'releaseYear', 'imdbId', 'imdbAverageRating',
#        'imdbNumVotes', 'availableCountries'],
#       dtype='object')

# %% [markdown]
# View the column data types

# %%
First_netflix_data.dtypes
# Out:
# Unnamed: 0    object
# id             int64
# type          object
# name          object
# creator       object
# starring      object
# year           int64
# rating        object
# time          object
# genres        object
# country       object
# describle     object
# dtype: object

# %% [markdown]
# Check for inconsistencies - view the unique values in the quantitative columns

# %%
First_netflix_data['type'].unique()
# Out:
# array(['Movie', 'TV Show'], dtype=object)

# %% [markdown]
# Print the unique values in the genres column

# %%
First_netflix_data['genres'].unique()
# Out:
# array(['Comedy, Crime, Drama', 'Comedy, Drama, Music', 'Drama, Romance',
#        'Drama', 'Action, Adventure, Sci-Fi', 'Biography, Drama, War',
#        'Drama, Western', 'Drama, Romance, Sci-Fi', 'Drama, Thriller',
#        'Action, Crime, Drama', 'Drama, Mystery, Romance', 'Drama, Music',
#        'Crime, Drama, Thriller', 'Drama, Sport', 'Crime, Drama',
#        'Comedy, Sci-Fi', 'Comedy, Drama, Romance', 'Mystery, Thriller',
#        'Action, Adventure, Drama', 'Adventure, Animation, Sci-Fi',
#        'Adventure, Drama, Horror', 'Action, Adventure',
#        'Drama, Music, Romance', 'Action, Comedy, Crime',
#        'Action, Crime, Thriller', 'Adventure, Comedy, Sci-Fi',
#        'Comedy, Crime', 'Adventure, Comedy, Family',
#        'Adventure, Drama, Fantasy', 'Adventure, Animation, Fantasy',
#        'Adventure, Animation, Family', 'Adventure, Comedy, Crime',
#        'Comedy, Drama, Fantasy', 'Drama, Mystery, Sci-Fi',
# ...

# %% [markdown]
# Check for null values

# %%
nan_count = original_netflix_data.isna().sum()
nan_count
# Out:
# title                   728
# type                      0
# genres                  369
# releaseYear              39
# imdbId                 1636
# imdbAverageRating      1814
# imdbNumVotes           1814
# availableCountries    21756
# dtype: int64

# %% [markdown]
# print number of rows in the column

# %%
original_netflix_data.shape
# Out:
# (21910, 8)

# %%
original_netflix_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21910 entries, 0 to 21909
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   title               21182 non-null  object
#  1   type                21910 non-null  object
#  2   genres              21541 non-null  object
#  3   releaseYear         21871 non-null  float64
#  4   imdbId              20274 non-null  object
#  5   imdbAverageRating   20096 non-null  float64
#  6   imdbNumVotes        20096 non-null  float64
#  7   availableCountries  154 non-null    object
# dtypes: float64(3), object(5)
# memory usage: 1.3+ MB

# %%
print(First_netflix_data.head())
# Out:
#   Unnamed: 0        id   type                          name creator  \
# 0       Full  81416533  Movie                Heart of Stone     NaN
# 1       Full  80991406  Movie  Johnny English Strikes Again     NaN
# 2       Full  81644420  Movie                          Hunt     NaN
# 3       Full  70208104  Movie                    Safe House     NaN
# 4       Full  70297761  Movie                    Commitment     NaN
#
#                                          starring  year rating     time  \
# 0             Gal Gadot, Jamie Dornan, Alia Bhatt  2023  TV-PG  125 min
# 1       Rowan Atkinson, Ben Miller, Emma Thompson  2018  TV-PG   88 min
# 2       Lee Jung-jae, Jung Woo-sung, Jeon Hye-jin  2022  TV-14  125 min
# 3  Denzel Washington, Ryan Reynolds, Vera Farmiga  2012  TV-14  114 min
# 4        Choi Seung-hyun, Han Ye-ri, Yoon Je-moon  2013  TV-14  112 min
#
#                                               genres        country  \
# ...
